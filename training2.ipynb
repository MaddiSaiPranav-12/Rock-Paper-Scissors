# %%
import glob
import os

data_path = 'UCF101_frames'  # your extracted frames root folder

class_folders = glob.glob(os.path.join(data_path, '*'))  # class folders
print(f'Number of classes found: {len(class_folders)}')

total_pngs = 0
for cls in class_folders:
    video_folders = glob.glob(os.path.join(cls, '*'))  # video folders inside class
    print(f'Class: {cls}, Number of videos: {len(video_folders)}')
    for vid in video_folders:
        png_files = glob.glob(os.path.join(vid, '*.png'))
        print(f'Video: {vid}, PNG count: {len(png_files)}')
        total_pngs += len(png_files)

print(f'Total PNG frames found: {total_pngs}')
# Out:
# Number of classes found: 15
# Class: UCF101_frames\ApplyEyeMakeup, Number of videos: 101
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g08_c01, PNG count: 120
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g08_c02, PNG count: 117
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g08_c03, PNG count: 146
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g08_c04, PNG count: 224
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g08_c05, PNG count: 276
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g09_c01, PNG count: 176
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g09_c02, PNG count: 258
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g09_c03, PNG count: 210
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g09_c04, PNG count: 191
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g09_c05, PNG count: 194
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g09_c06, PNG count: 188
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g09_c07, PNG count: 261
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g10_c01, PNG count: 153
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g10_c02, PNG count: 98
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g10_c03, PNG count: 106
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g10_c04, PNG count: 124
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g10_c05, PNG count: 120
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g11_c01, PNG count: 140
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g11_c02, PNG count: 178
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g11_c03, PNG count: 125
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g11_c04, PNG count: 138
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g11_c05, PNG count: 180
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g12_c01, PNG count: 226
# Video: UCF101_frames\ApplyEyeMakeup\v_ApplyEyeMakeup_g12_c02, PNG count: 120
# Video: UCF101_frames\Basketball\v_Basketball_g09_c05, PNG count: 122
# Video: UCF101_frames\Basketball\v_Basketball_g10_c01, PNG count: 128
# Video: UCF101_frames\Basketball\v_Basketball_g10_c02, PNG count: 124
# Video: UCF101_frames\Basketball\v_Basketball_g10_c03, PNG count: 116
# Video: UCF101_frames\Basketball\v_Basketball_g10_c04, PNG count: 103
# Video: UCF101_frames\Basketball\v_Basketball_g10_c05, PNG count: 117
# Video: UCF101_frames\Basketball\v_Basketball_g11_c01, PNG count: 105
# Video: UCF101_frames\Basketball\v_Basketball_g11_c02, PNG count: 143
# Video: UCF101_frames\Basketball\v_Basketball_g11_c03, PNG count: 75
# Video: UCF101_frames\Basketball\v_Basketball_g11_c04, PNG count: 77
# Video: UCF101_frames\Basketball\v_Basketball_g11_c05, PNG count: 87
# Video: UCF101_frames\Basketball\v_Basketball_g12_c01, PNG count: 273
# Video: UCF101_frames\Basketball\v_Basketball_g12_c02, PNG count: 184
# Video: UCF101_frames\Basketball\v_Basketball_g12_c03, PNG count: 137
# Video: UCF101_frames\Basketball\v_Basketball_g12_c04, PNG count: 228
# Video: UCF101_frames\Basketball\v_Basketball_g12_c05, PNG count: 230
# Video: UCF101_frames\Basketball\v_Basketball_g13_c01, PNG count: 299
# Video: UCF101_frames\Basketball\v_Basketball_g13_c02, PNG count: 324
# Video: UCF101_frames\Basketball\v_Basketball_g13_c03, PNG count: 311
# Video: UCF101_frames\Basketball\v_Basketball_g13_c04, PNG count: 293
# Video: UCF101_frames\Basketball\v_Basketball_g14_c01, PNG count: 81
# Video: UCF101_frames\Basketball\v_Basketball_g14_c02, PNG count: 131
# Video: UCF101_frames\Basketball\v_Basketball_g14_c03, PNG count: 89
# Video: UCF101_frames\Basketball\v_Basketball_g14_c04, PNG count: 88
# Video: UCF101_frames\Basketball\v_Basketball_g14_c05, PNG count: 91
# Video: UCF101_frames\Basketball\v_Basketball_g15_c01, PNG count: 120
# Video: UCF101_frames\Basketball\v_Basketball_g15_c02, PNG count: 152
# Video: UCF101_frames\Basketball\v_Basketball_g15_c03, PNG count: 195
# Video: UCF101_frames\Basketball\v_Basketball_g15_c04, PNG count: 112
# Video: UCF101_frames\Basketball\v_Basketball_g15_c05, PNG count: 174
# Video: UCF101_frames\Basketball\v_Basketball_g15_c06, PNG count: 185
# Video: UCF101_frames\Basketball\v_Basketball_g15_c07, PNG count: 164
# Video: UCF101_frames\Basketball\v_Basketball_g16_c01, PNG count: 482
# Video: UCF101_frames\Basketball\v_Basketball_g16_c02, PNG count: 492
# Video: UCF101_frames\Basketball\v_Basketball_g16_c03, PNG count: 125
# Video: UCF101_frames\Basketball\v_Basketball_g16_c04, PNG count: 90
# Video: UCF101_frames\Basketball\v_Basketball_g16_c05, PNG count: 446
# Video: UCF101_frames\Basketball\v_Basketball_g16_c06, PNG count: 315
# Video: UCF101_frames\Basketball\v_Basketball_g17_c01, PNG count: 153
# Video: UCF101_frames\Basketball\v_Basketball_g17_c02, PNG count: 114
# Video: UCF101_frames\Basketball\v_Basketball_g17_c03, PNG count: 214
# Video: UCF101_frames\Basketball\v_Basketball_g17_c04, PNG count: 84
# Video: UCF101_frames\Basketball\v_Basketball_g18_c01, PNG count: 236
# Video: UCF101_frames\Basketball\v_Basketball_g18_c02, PNG count: 102
# Video: UCF101_frames\Basketball\v_Basketball_g18_c03, PNG count: 174
# Video: UCF101_frames\Basketball\v_Basketball_g18_c04, PNG count: 187
# Video: UCF101_frames\Basketball\v_Basketball_g18_c05, PNG count: 143
# Video: UCF101_frames\Basketball\v_Basketball_g19_c01, PNG count: 78
# Video: UCF101_frames\Basketball\v_Basketball_g19_c02, PNG count: 143
# Video: UCF101_frames\Basketball\v_Basketball_g19_c03, PNG count: 120
# Video: UCF101_frames\Basketball\v_Basketball_g19_c04, PNG count: 118
# Video: UCF101_frames\Basketball\v_Basketball_g19_c05, PNG count: 151
# Video: UCF101_frames\Basketball\v_Basketball_g19_c06, PNG count: 101
# Video: UCF101_frames\Basketball\v_Basketball_g19_c07, PNG count: 137
# Video: UCF101_frames\Basketball\v_Basketball_g20_c01, PNG count: 120
# Video: UCF101_frames\Basketball\v_Basketball_g20_c02, PNG count: 175
# Video: UCF101_frames\Basketball\v_Basketball_g20_c03, PNG count: 105
# Video: UCF101_frames\Basketball\v_Basketball_g20_c04, PNG count: 120
# Video: UCF101_frames\Basketball\v_Basketball_g20_c05, PNG count: 120
# Video: UCF101_frames\Basketball\v_Basketball_g20_c06, PNG count: 88
# Video: UCF101_frames\Basketball\v_Basketball_g20_c07, PNG count: 74
# Video: UCF101_frames\Basketball\v_Basketball_g21_c01, PNG count: 70
# Video: UCF101_frames\Basketball\v_Basketball_g21_c02, PNG count: 100
# Video: UCF101_frames\Basketball\v_Basketball_g21_c03, PNG count: 182
# Video: UCF101_frames\Basketball\v_Basketball_g21_c04, PNG count: 130
# Video: UCF101_frames\Basketball\v_Basketball_g21_c05, PNG count: 180
# Video: UCF101_frames\Basketball\v_Basketball_g21_c06, PNG count: 84
# Video: UCF101_frames\Basketball\v_Basketball_g22_c01, PNG count: 120
# Video: UCF101_frames\Basketball\v_Basketball_g22_c02, PNG count: 102
# Video: UCF101_frames\Basketball\v_Basketball_g22_c03, PNG count: 132
# Video: UCF101_frames\Basketball\v_Basketball_g22_c04, PNG count: 101
# Video: UCF101_frames\Basketball\v_Basketball_g22_c05, PNG count: 88
# Video: UCF101_frames\Basketball\v_Basketball_g22_c06, PNG count: 101
# Video: UCF101_frames\Basketball\v_Basketball_g22_c07, PNG count: 99
# Video: UCF101_frames\Basketball\v_Basketball_g23_c01, PNG count: 138
# Video: UCF101_frames\Basketball\v_Basketball_g23_c02, PNG count: 120
# Video: UCF101_frames\Basketball\v_Basketball_g23_c03, PNG count: 120
# Video: UCF101_frames\Basketball\v_Basketball_g23_c04, PNG count: 119
# Video: UCF101_frames\Basketball\v_Basketball_g23_c05, PNG count: 103
# Video: UCF101_frames\Basketball\v_Basketball_g23_c06, PNG count: 97
# Video: UCF101_frames\Basketball\v_Basketball_g24_c01, PNG count: 133
# Video: UCF101_frames\Basketball\v_Basketball_g24_c02, PNG count: 120
# Video: UCF101_frames\Basketball\v_Basketball_g24_c03, PNG count: 117
# Video: UCF101_frames\Basketball\v_Basketball_g24_c04, PNG count: 120
# Video: UCF101_frames\Basketball\v_Basketball_g25_c01, PNG count: 125
# Video: UCF101_frames\Basketball\v_Basketball_g25_c02, PNG count: 179
# Video: UCF101_frames\Basketball\v_Basketball_g25_c03, PNG count: 146
# Video: UCF101_frames\Basketball\v_Basketball_g25_c04, PNG count: 108
# Video: UCF101_frames\Basketball\v_Basketball_g25_c05, PNG count: 180
# Video: UCF101_frames\Basketball\v_Basketball_g25_c06, PNG count: 111
# Video: UCF101_frames\Basketball\v_Basketball_g25_c07, PNG count: 131
# Class: UCF101_frames\BenchPress, Number of videos: 112
# Video: UCF101_frames\BenchPress\v_BenchPress_g08_c01, PNG count: 64
# Video: UCF101_frames\BenchPress\v_BenchPress_g08_c02, PNG count: 61
# Video: UCF101_frames\BenchPress\v_BenchPress_g08_c03, PNG count: 57
# Video: UCF101_frames\BenchPress\v_BenchPress_g08_c04, PNG count: 60
# Video: UCF101_frames\BenchPress\v_BenchPress_g08_c05, PNG count: 187
# Video: UCF101_frames\BenchPress\v_BenchPress_g08_c06, PNG count: 86
# Video: UCF101_frames\BenchPress\v_BenchPress_g08_c07, PNG count: 72
# Video: UCF101_frames\BenchPress\v_BenchPress_g09_c01, PNG count: 85
# Video: UCF101_frames\BenchPress\v_BenchPress_g09_c02, PNG count: 70
# Video: UCF101_frames\BenchPress\v_BenchPress_g09_c03, PNG count: 69
# Video: UCF101_frames\BenchPress\v_BenchPress_g09_c04, PNG count: 68
# Video: UCF101_frames\BenchPress\v_BenchPress_g09_c05, PNG count: 63
# Video: UCF101_frames\BenchPress\v_BenchPress_g09_c06, PNG count: 211
# Video: UCF101_frames\BenchPress\v_BenchPress_g09_c07, PNG count: 109
# Video: UCF101_frames\BenchPress\v_BenchPress_g10_c01, PNG count: 112
# Video: UCF101_frames\BenchPress\v_BenchPress_g10_c02, PNG count: 108
# Video: UCF101_frames\BenchPress\v_BenchPress_g10_c03, PNG count: 243
# Video: UCF101_frames\BenchPress\v_BenchPress_g10_c04, PNG count: 134
# Video: UCF101_frames\BenchPress\v_BenchPress_g11_c01, PNG count: 98
# Video: UCF101_frames\BenchPress\v_BenchPress_g11_c02, PNG count: 95
# Video: UCF101_frames\BenchPress\v_BenchPress_g11_c03, PNG count: 93
# Video: UCF101_frames\BenchPress\v_BenchPress_g11_c04, PNG count: 251
# Video: UCF101_frames\BenchPress\v_BenchPress_g11_c05, PNG count: 114
# Video: UCF101_frames\BenchPress\v_BenchPress_g12_c01, PNG count: 65
# Video: UCF101_frames\BenchPress\v_BenchPress_g12_c02, PNG count: 63
# Video: UCF101_frames\BenchPress\v_BenchPress_g12_c03, PNG count: 194
# Video: UCF101_frames\BenchPress\v_BenchPress_g12_c04, PNG count: 103
# Video: UCF101_frames\BenchPress\v_BenchPress_g12_c05, PNG count: 84
# Video: UCF101_frames\BenchPress\v_BenchPress_g12_c06, PNG count: 73
# Video: UCF101_frames\BenchPress\v_BenchPress_g12_c07, PNG count: 68
# Video: UCF101_frames\BenchPress\v_BenchPress_g13_c01, PNG count: 140
# Video: UCF101_frames\BenchPress\v_BenchPress_g13_c02, PNG count: 93
# Video: UCF101_frames\BenchPress\v_BenchPress_g13_c03, PNG count: 200
# Video: UCF101_frames\BenchPress\v_BenchPress_g13_c04, PNG count: 146
# Video: UCF101_frames\BenchPress\v_BenchPress_g13_c05, PNG count: 141
# Video: UCF101_frames\BenchPress\v_BenchPress_g13_c06, PNG count: 102
# Video: UCF101_frames\BenchPress\v_BenchPress_g13_c07, PNG count: 103
# Video: UCF101_frames\BenchPress\v_BenchPress_g14_c01, PNG count: 96
# Video: UCF101_frames\BenchPress\v_BenchPress_g14_c02, PNG count: 99
# Video: UCF101_frames\BenchPress\v_BenchPress_g14_c03, PNG count: 105
# Video: UCF101_frames\BenchPress\v_BenchPress_g14_c04, PNG count: 305
# Video: UCF101_frames\BenchPress\v_BenchPress_g14_c05, PNG count: 212
# Video: UCF101_frames\BenchPress\v_BenchPress_g14_c06, PNG count: 178
# Video: UCF101_frames\BenchPress\v_BenchPress_g14_c07, PNG count: 105
# Video: UCF101_frames\BenchPress\v_BenchPress_g15_c01, PNG count: 67
# Video: UCF101_frames\BenchPress\v_BenchPress_g15_c02, PNG count: 64
# Video: UCF101_frames\BenchPress\v_BenchPress_g15_c03, PNG count: 72
# Video: UCF101_frames\BenchPress\v_BenchPress_g15_c04, PNG count: 170
# Video: UCF101_frames\BenchPress\v_BenchPress_g15_c05, PNG count: 65
# Video: UCF101_frames\BenchPress\v_BenchPress_g15_c06, PNG count: 45
# Video: UCF101_frames\BenchPress\v_BenchPress_g16_c01, PNG count: 107
# Video: UCF101_frames\BenchPress\v_BenchPress_g16_c02, PNG count: 99
# Video: UCF101_frames\BenchPress\v_BenchPress_g16_c03, PNG count: 100
# Video: UCF101_frames\BenchPress\v_BenchPress_g16_c04, PNG count: 218
# Video: UCF101_frames\BenchPress\v_BenchPress_g16_c05, PNG count: 124
# Video: UCF101_frames\BenchPress\v_BenchPress_g17_c01, PNG count: 71
# Video: UCF101_frames\BenchPress\v_BenchPress_g17_c02, PNG count: 68
# Video: UCF101_frames\BenchPress\v_BenchPress_g17_c03, PNG count: 65
# Video: UCF101_frames\BenchPress\v_BenchPress_g17_c04, PNG count: 312
# Video: UCF101_frames\BenchPress\v_BenchPress_g17_c05, PNG count: 172
# Video: UCF101_frames\BenchPress\v_BenchPress_g17_c06, PNG count: 117
# Video: UCF101_frames\BenchPress\v_BenchPress_g17_c07, PNG count: 72
# Video: UCF101_frames\BenchPress\v_BenchPress_g18_c01, PNG count: 93
# Video: UCF101_frames\BenchPress\v_BenchPress_g18_c02, PNG count: 101
# Video: UCF101_frames\BenchPress\v_BenchPress_g18_c03, PNG count: 274
# Video: UCF101_frames\BenchPress\v_BenchPress_g18_c04, PNG count: 127
# Video: UCF101_frames\BenchPress\v_BenchPress_g18_c05, PNG count: 112
# Video: UCF101_frames\BenchPress\v_BenchPress_g18_c06, PNG count: 110
# Video: UCF101_frames\BenchPress\v_BenchPress_g18_c07, PNG count: 78
# Video: UCF101_frames\BenchPress\v_BenchPress_g19_c01, PNG count: 92
# Video: UCF101_frames\BenchPress\v_BenchPress_g19_c02, PNG count: 86
# Video: UCF101_frames\BenchPress\v_BenchPress_g19_c03, PNG count: 82
# Video: UCF101_frames\BenchPress\v_BenchPress_g19_c04, PNG count: 249
# Video: UCF101_frames\BenchPress\v_BenchPress_g19_c05, PNG count: 121
# Video: UCF101_frames\BenchPress\v_BenchPress_g19_c06, PNG count: 103
# Video: UCF101_frames\BenchPress\v_BenchPress_g20_c01, PNG count: 87
# Video: UCF101_frames\BenchPress\v_BenchPress_g20_c02, PNG count: 81
# Video: UCF101_frames\BenchPress\v_BenchPress_g20_c03, PNG count: 91
# Video: UCF101_frames\BenchPress\v_BenchPress_g20_c04, PNG count: 210
# Video: UCF101_frames\BenchPress\v_BenchPress_g20_c05, PNG count: 90
# Video: UCF101_frames\BenchPress\v_BenchPress_g20_c06, PNG count: 88
# Video: UCF101_frames\BenchPress\v_BenchPress_g20_c07, PNG count: 81
# Video: UCF101_frames\BenchPress\v_BenchPress_g21_c01, PNG count: 188
# Video: UCF101_frames\BenchPress\v_BenchPress_g21_c02, PNG count: 110
# Video: UCF101_frames\BenchPress\v_BenchPress_g21_c03, PNG count: 93
# Video: UCF101_frames\BenchPress\v_BenchPress_g21_c04, PNG count: 291
# Video: UCF101_frames\BenchPress\v_BenchPress_g22_c01, PNG count: 88
# Video: UCF101_frames\BenchPress\v_BenchPress_g22_c02, PNG count: 78
# Video: UCF101_frames\BenchPress\v_BenchPress_g22_c03, PNG count: 74
# Video: UCF101_frames\BenchPress\v_BenchPress_g22_c04, PNG count: 71
# Video: UCF101_frames\BenchPress\v_BenchPress_g22_c05, PNG count: 71
# Video: UCF101_frames\BenchPress\v_BenchPress_g22_c06, PNG count: 274
# Video: UCF101_frames\BenchPress\v_BenchPress_g22_c07, PNG count: 132
# Video: UCF101_frames\BenchPress\v_BenchPress_g23_c01, PNG count: 131
# Video: UCF101_frames\BenchPress\v_BenchPress_g23_c02, PNG count: 126
# Video: UCF101_frames\BenchPress\v_BenchPress_g23_c03, PNG count: 176
# Video: UCF101_frames\BenchPress\v_BenchPress_g23_c04, PNG count: 164
# Video: UCF101_frames\BenchPress\v_BenchPress_g23_c05, PNG count: 127
# Video: UCF101_frames\BenchPress\v_BenchPress_g24_c01, PNG count: 69
# Video: UCF101_frames\BenchPress\v_BenchPress_g24_c02, PNG count: 69
# Video: UCF101_frames\BenchPress\v_BenchPress_g24_c03, PNG count: 64
# Video: UCF101_frames\BenchPress\v_BenchPress_g24_c04, PNG count: 166
# Video: UCF101_frames\BenchPress\v_BenchPress_g24_c05, PNG count: 111
# Video: UCF101_frames\BenchPress\v_BenchPress_g24_c06, PNG count: 80
# Video: UCF101_frames\BenchPress\v_BenchPress_g24_c07, PNG count: 74
# Video: UCF101_frames\BenchPress\v_BenchPress_g25_c01, PNG count: 107
# Video: UCF101_frames\BenchPress\v_BenchPress_g25_c02, PNG count: 108
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g08_c02, PNG count: 151
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g08_c03, PNG count: 151
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g08_c04, PNG count: 151
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g08_c05, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g08_c06, PNG count: 175
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g09_c01, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g09_c02, PNG count: 170
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g09_c03, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g09_c04, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g09_c05, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g09_c06, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g10_c01, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g10_c02, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g10_c03, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g10_c04, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g10_c05, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g10_c06, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g10_c07, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g11_c01, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g11_c02, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g11_c03, PNG count: 151
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g11_c04, PNG count: 151
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g11_c05, PNG count: 151
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g11_c06, PNG count: 151
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g11_c07, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g12_c01, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g12_c02, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g12_c03, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g12_c04, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g12_c05, PNG count: 140
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g12_c06, PNG count: 204
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g12_c07, PNG count: 174
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g13_c01, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g13_c02, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g13_c03, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g13_c04, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g14_c01, PNG count: 153
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g14_c02, PNG count: 32
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g14_c03, PNG count: 93
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g14_c04, PNG count: 93
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g14_c05, PNG count: 180
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g14_c06, PNG count: 180
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g14_c07, PNG count: 180
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g15_c01, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g15_c02, PNG count: 157
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g15_c03, PNG count: 171
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g15_c04, PNG count: 151
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g15_c05, PNG count: 151
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g15_c06, PNG count: 151
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g16_c01, PNG count: 161
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g16_c02, PNG count: 161
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g16_c03, PNG count: 161
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g16_c04, PNG count: 169
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g16_c05, PNG count: 300
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g16_c06, PNG count: 311
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g17_c01, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g17_c02, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g17_c03, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g17_c04, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g17_c05, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g17_c06, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g18_c01, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g18_c02, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g18_c03, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g18_c04, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g18_c05, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g18_c06, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g19_c01, PNG count: 192
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g19_c02, PNG count: 180
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g19_c03, PNG count: 191
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g19_c04, PNG count: 180
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g19_c05, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g19_c06, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g19_c07, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g20_c01, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g20_c02, PNG count: 175
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g20_c03, PNG count: 176
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g20_c04, PNG count: 163
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g20_c05, PNG count: 163
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g20_c06, PNG count: 212
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g20_c07, PNG count: 180
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g21_c01, PNG count: 171
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g21_c02, PNG count: 146
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g21_c03, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g21_c04, PNG count: 167
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g21_c05, PNG count: 189
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g21_c06, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g22_c01, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g22_c02, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g22_c03, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g22_c04, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g22_c05, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g22_c06, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g22_c07, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g23_c01, PNG count: 196
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g23_c02, PNG count: 251
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g23_c03, PNG count: 151
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g23_c04, PNG count: 126
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g23_c05, PNG count: 180
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g23_c06, PNG count: 201
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g24_c01, PNG count: 151
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g24_c02, PNG count: 188
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g24_c03, PNG count: 151
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g24_c04, PNG count: 180
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g24_c05, PNG count: 180
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g24_c06, PNG count: 180
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g24_c07, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g25_c01, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g25_c02, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g25_c03, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g25_c04, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g25_c05, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g25_c06, PNG count: 240
# Video: UCF101_frames\HorseRiding\v_HorseRiding_g25_c07, PNG count: 240
# Class: UCF101_frames\JumpRope, Number of videos: 106
# Video: UCF101_frames\JumpRope\v_JumpRope_g08_c01, PNG count: 497
# Video: UCF101_frames\JumpRope\v_JumpRope_g08_c02, PNG count: 443
# Video: UCF101_frames\JumpRope\v_JumpRope_g08_c03, PNG count: 526
# Video: UCF101_frames\JumpRope\v_JumpRope_g08_c04, PNG count: 350
# Video: UCF101_frames\JumpRope\v_JumpRope_g08_c05, PNG count: 509
# Video: UCF101_frames\JumpRope\v_JumpRope_g08_c06, PNG count: 356
# Video: UCF101_frames\JumpRope\v_JumpRope_g08_c07, PNG count: 459
# Video: UCF101_frames\JumpRope\v_JumpRope_g09_c01, PNG count: 472
# Video: UCF101_frames\JumpRope\v_JumpRope_g09_c02, PNG count: 501
# Video: UCF101_frames\JumpRope\v_JumpRope_g09_c03, PNG count: 500
# Video: UCF101_frames\JumpRope\v_JumpRope_g09_c04, PNG count: 510
# Video: UCF101_frames\JumpRope\v_JumpRope_g09_c05, PNG count: 510
# Video: UCF101_frames\JumpRope\v_JumpRope_g09_c06, PNG count: 491
# Video: UCF101_frames\JumpRope\v_JumpRope_g09_c07, PNG count: 491
# Video: UCF101_frames\JumpRope\v_JumpRope_g10_c01, PNG count: 598
# Video: UCF101_frames\JumpRope\v_JumpRope_g10_c02, PNG count: 600
# Video: UCF101_frames\JumpRope\v_JumpRope_g10_c03, PNG count: 604
# Video: UCF101_frames\JumpRope\v_JumpRope_g10_c04, PNG count: 570
# Video: UCF101_frames\JumpRope\v_JumpRope_g11_c01, PNG count: 533
# Video: UCF101_frames\JumpRope\v_JumpRope_g11_c02, PNG count: 533
# Video: UCF101_frames\JumpRope\v_JumpRope_g11_c03, PNG count: 495
# Video: UCF101_frames\JumpRope\v_JumpRope_g11_c04, PNG count: 518
# Video: UCF101_frames\JumpRope\v_JumpRope_g11_c05, PNG count: 495
# Video: UCF101_frames\JumpRope\v_JumpRope_g11_c06, PNG count: 510
# Video: UCF101_frames\JumpRope\v_JumpRope_g11_c07, PNG count: 496
# Video: UCF101_frames\JumpRope\v_JumpRope_g12_c01, PNG count: 374
# Video: UCF101_frames\JumpRope\v_JumpRope_g12_c02, PNG count: 403
# Video: UCF101_frames\JumpRope\v_JumpRope_g12_c03, PNG count: 398
# Video: UCF101_frames\JumpRope\v_JumpRope_g12_c04, PNG count: 398
# Video: UCF101_frames\JumpRope\v_JumpRope_g12_c05, PNG count: 403
# Video: UCF101_frames\JumpRope\v_JumpRope_g13_c01, PNG count: 539
# Video: UCF101_frames\JumpRope\v_JumpRope_g13_c02, PNG count: 422
# Video: UCF101_frames\JumpRope\v_JumpRope_g13_c03, PNG count: 482
# Video: UCF101_frames\JumpRope\v_JumpRope_g13_c04, PNG count: 374
# Video: UCF101_frames\JumpRope\v_JumpRope_g13_c05, PNG count: 391
# Video: UCF101_frames\JumpRope\v_JumpRope_g14_c01, PNG count: 296
# Video: UCF101_frames\JumpRope\v_JumpRope_g14_c02, PNG count: 305
# Video: UCF101_frames\JumpRope\v_JumpRope_g14_c03, PNG count: 298
# Video: UCF101_frames\JumpRope\v_JumpRope_g14_c04, PNG count: 306
# Video: UCF101_frames\JumpRope\v_JumpRope_g15_c01, PNG count: 548
# Video: UCF101_frames\JumpRope\v_JumpRope_g15_c02, PNG count: 352
# Video: UCF101_frames\JumpRope\v_JumpRope_g15_c03, PNG count: 488
# Video: UCF101_frames\JumpRope\v_JumpRope_g15_c04, PNG count: 489
# Video: UCF101_frames\JumpRope\v_JumpRope_g15_c05, PNG count: 531
# Video: UCF101_frames\JumpRope\v_JumpRope_g15_c06, PNG count: 496
# Video: UCF101_frames\JumpRope\v_JumpRope_g16_c01, PNG count: 539
# Video: UCF101_frames\JumpRope\v_JumpRope_g16_c02, PNG count: 486
# Video: UCF101_frames\JumpRope\v_JumpRope_g16_c03, PNG count: 507
# Video: UCF101_frames\JumpRope\v_JumpRope_g16_c04, PNG count: 507
# Video: UCF101_frames\JumpRope\v_JumpRope_g16_c05, PNG count: 485
# Video: UCF101_frames\JumpRope\v_JumpRope_g16_c06, PNG count: 529
# Video: UCF101_frames\JumpRope\v_JumpRope_g16_c07, PNG count: 464
# Video: UCF101_frames\JumpRope\v_JumpRope_g17_c01, PNG count: 614
# Video: UCF101_frames\JumpRope\v_JumpRope_g17_c02, PNG count: 599
# Video: UCF101_frames\JumpRope\v_JumpRope_g17_c03, PNG count: 586
# Video: UCF101_frames\JumpRope\v_JumpRope_g17_c04, PNG count: 613
# Video: UCF101_frames\JumpRope\v_JumpRope_g17_c05, PNG count: 575
# Video: UCF101_frames\JumpRope\v_JumpRope_g18_c01, PNG count: 364
# Video: UCF101_frames\JumpRope\v_JumpRope_g18_c02, PNG count: 417
# Video: UCF101_frames\JumpRope\v_JumpRope_g18_c03, PNG count: 447
# Video: UCF101_frames\JumpRope\v_JumpRope_g18_c04, PNG count: 382
# Video: UCF101_frames\JumpRope\v_JumpRope_g18_c05, PNG count: 416
# Video: UCF101_frames\JumpRope\v_JumpRope_g18_c06, PNG count: 599
# Video: UCF101_frames\JumpRope\v_JumpRope_g18_c07, PNG count: 405
# Video: UCF101_frames\JumpRope\v_JumpRope_g19_c01, PNG count: 307
# Video: UCF101_frames\JumpRope\v_JumpRope_g19_c02, PNG count: 293
# Video: UCF101_frames\JumpRope\v_JumpRope_g19_c03, PNG count: 335
# Video: UCF101_frames\JumpRope\v_JumpRope_g19_c04, PNG count: 476
# Video: UCF101_frames\JumpRope\v_JumpRope_g20_c01, PNG count: 458
# Video: UCF101_frames\JumpRope\v_JumpRope_g20_c02, PNG count: 527
# Video: UCF101_frames\JumpRope\v_JumpRope_g20_c03, PNG count: 509
# Video: UCF101_frames\JumpRope\v_JumpRope_g20_c04, PNG count: 510
# Video: UCF101_frames\JumpRope\v_JumpRope_g20_c05, PNG count: 492
# Video: UCF101_frames\JumpRope\v_JumpRope_g20_c06, PNG count: 526
# Video: UCF101_frames\JumpRope\v_JumpRope_g20_c07, PNG count: 476
# Video: UCF101_frames\JumpRope\v_JumpRope_g21_c01, PNG count: 491
# Video: UCF101_frames\JumpRope\v_JumpRope_g21_c02, PNG count: 445
# Video: UCF101_frames\JumpRope\v_JumpRope_g21_c03, PNG count: 525
# Video: UCF101_frames\JumpRope\v_JumpRope_g21_c04, PNG count: 503
# Video: UCF101_frames\JumpRope\v_JumpRope_g21_c05, PNG count: 502
# Video: UCF101_frames\JumpRope\v_JumpRope_g21_c06, PNG count: 490
# Video: UCF101_frames\JumpRope\v_JumpRope_g21_c07, PNG count: 432
# Video: UCF101_frames\JumpRope\v_JumpRope_g22_c01, PNG count: 198
# Video: UCF101_frames\JumpRope\v_JumpRope_g22_c02, PNG count: 209
# Video: UCF101_frames\JumpRope\v_JumpRope_g22_c03, PNG count: 212
# Video: UCF101_frames\JumpRope\v_JumpRope_g22_c04, PNG count: 246
# Video: UCF101_frames\JumpRope\v_JumpRope_g22_c05, PNG count: 189
# Video: UCF101_frames\JumpRope\v_JumpRope_g22_c06, PNG count: 221
# Video: UCF101_frames\JumpRope\v_JumpRope_g23_c01, PNG count: 343
# Video: UCF101_frames\JumpRope\v_JumpRope_g23_c02, PNG count: 310
# Video: UCF101_frames\JumpRope\v_JumpRope_g23_c03, PNG count: 340
# Video: UCF101_frames\JumpRope\v_JumpRope_g23_c04, PNG count: 406
# Video: UCF101_frames\JumpRope\v_JumpRope_g23_c05, PNG count: 242
# Video: UCF101_frames\JumpRope\v_JumpRope_g24_c01, PNG count: 410
# Video: UCF101_frames\JumpRope\v_JumpRope_g24_c02, PNG count: 391
# Video: UCF101_frames\JumpRope\v_JumpRope_g24_c03, PNG count: 411
# Video: UCF101_frames\JumpRope\v_JumpRope_g24_c04, PNG count: 430
# Video: UCF101_frames\JumpRope\v_JumpRope_g24_c05, PNG count: 358
# Video: UCF101_frames\JumpRope\v_JumpRope_g24_c06, PNG count: 384
# Video: UCF101_frames\JumpRope\v_JumpRope_g24_c07, PNG count: 436
# Video: UCF101_frames\JumpRope\v_JumpRope_g25_c01, PNG count: 400
# Video: UCF101_frames\JumpRope\v_JumpRope_g25_c02, PNG count: 408
# Video: UCF101_frames\JumpRope\v_JumpRope_g25_c03, PNG count: 391
# Video: UCF101_frames\JumpRope\v_JumpRope_g25_c04, PNG count: 408
# Video: UCF101_frames\JumpRope\v_JumpRope_g25_c05, PNG count: 391
# Video: UCF101_frames\JumpRope\v_JumpRope_g25_c06, PNG count: 408
# Total PNG frames found: 299356

# %%
import os
import tensorflow as tf
import cv2
import numpy as np
from datetime import datetime
from vgg16_keras import VGG16FeatureExtractor 
from CyclicGen_model import Voxel_flow_model
# ==== YOUR 15 TARGET CLASSES ====
TARGET_CLASSES = [
    'ApplyEyeMakeup', 'Archery', 'BabyCrawling', 'Basketball', 'BenchPress',
    'Biking', 'Bowling', 'BoxingPunchingBag', 'CliffDiving', 'Diving',
    'Drumming', 'GolfSwing', 'Haircut', 'HorseRiding', 'JumpRope'
]

# %%
import os
import glob

def generate_triplets(data_dir, output_file):
    triplets = []
    classes = sorted(os.listdir(data_dir))
    for cls in classes:
        cls_path = os.path.join(data_dir, cls)
        if not os.path.isdir(cls_path):
            continue
        videos = sorted(os.listdir(cls_path))
        for vid in videos:
            vid_path = os.path.join(cls_path, vid)
            if not os.path.isdir(vid_path):
                continue
            frames = sorted(glob.glob(os.path.join(vid_path, '*')))
            for i in range(len(frames) - 2):
                triplet = f"{frames[i]} {frames[i+1]} {frames[i+2]}"
                triplets.append(triplet)
    with open(output_file, 'w') as f:
        for triplet in triplets:
            f.write(f"{triplet}\n")
    print(f"Generated {len(triplets)} triplets.")

# Usage
generate_triplets('D:/VFI/CyclicGen/UCF101_frames', 'triplets.txt')
# Out:
# Generated 296210 triplets.

# %%
import glob
frames = glob.glob("D:/VFI/CyclicGen/UCF101_frames/**/*.png", recursive=True)
print(f"Found {len(frames)} frames")
# Out:
# Found 299356 frames

# %%
def read_triplets_from_txt(txt_path):
    f1_list, f2_list, f3_list = [], [], []
    with open(txt_path, 'r') as file:
        for line in file:
            f1, f2, f3 = line.strip().split()
            f1_list.append(f1)
            f2_list.append(f2)
            f3_list.append(f3)
    return f1_list, f2_list, f3_list

# %%
def load_and_preprocess_image(path):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [256, 256])
    image = tf.cast(image, tf.float32) / 255.0
    return image

# %%
def create_dataset(file_list, batch_size):
    path_ds = tf.data.Dataset.from_tensor_slices(file_list)
    image_ds = path_ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    image_ds = image_ds.batch(batch_size).repeat()
    return iter(image_ds)  # Use Python iterator for TF 2.x

# %%
def get_vgg16_edge_features(input_tensor):
    base_model = tf.keras.applications.VGG16(include_top=False, weights='imagenet', input_tensor=input_tensor)
    edge_feature = base_model.get_layer('block5_conv3').output
    edge_feature = tf.nn.sigmoid(edge_feature)
    edge_feature = tf.image.resize(edge_feature, (256, 256))
    edge_feature = tf.reduce_mean(edge_feature, axis=-1, keepdims=True)
    return edge_feature

# %%
from CyclicGen_model import Voxel_flow_model
def train_epochwise_using_triplets(triplets_txt_path, batch_size, num_epochs, train_dir):
    if not os.path.exists(train_dir):
        os.makedirs(train_dir)

    f1_list, f2_list, f3_list = read_triplets_from_txt(triplets_txt_path)
    dataset_size = len(f1_list)
    steps_per_epoch = dataset_size // batch_size

    it1 = iter(create_dataset(f1_list, batch_size))
    it2 = iter(create_dataset(f2_list, batch_size))
    it3 = iter(create_dataset(f3_list, batch_size))

# Use eager tensors
    input1 = next(it1)
    input2 = next(it2)
    input3 = next(it3)

# Apply VGG and model in eager mode
    vgg_model = VGG16FeatureExtractor()
    edge_1 = vgg_model(input1)
    edge_3 = vgg_model(input3)

# Call model
    prediction = Voxel_flow_model(tf.concat([input1, input3, edge_1, edge_3], axis=3))

# Calculate loss
    loss = tf.reduce_mean(tf.abs(prediction - input2))

    with tf.variable_scope("Cycle_DVF"):
        model = Voxel_flow_model()
        concat_input = tf.concat([input1, input3, edge_1, edge_3], axis=3)
        prediction, flow = model.inference(concat_input)
        loss = model.l1loss(prediction, input2)

    trainable_vars = tf.trainable_variables()
    dof_vars = [v for v in trainable_vars if not 'vgg' in v.name]
    optimizer = tf.train.AdamOptimizer(1e-4).minimize(loss, var_list=dof_vars)

    saver = tf.train.Saver(tf.global_variables(), max_to_keep=50)
    summary_op = tf.summary.merge([
            tf.summary.scalar('loss', loss),
            tf.summary.image('input1', input1, 1),
            tf.summary.image('input2', input2, 1),
            tf.summary.image('input3', input3, 1),
            tf.summary.image('predicted', prediction, 1),
        ])

    loss_history = []

    with tf.Session(graph=g) as sess:
            sess.run(tf.global_variables_initializer())
            sess.run([it1.initializer, it2.initializer, it3.initializer])
            summary_writer = tf.summary.FileWriter(train_dir, sess.graph)

            for epoch in range(num_epochs):
                print(f"\nEpoch {epoch + 1}/{num_epochs}")
                total_loss = 0

                for step in range(steps_per_epoch):
                    _, loss_val = sess.run([optimizer, loss])
                    total_loss += loss_val

                    if step % 100 == 0:
                        summary_writer.add_summary(sess.run(summary_op), epoch * steps_per_epoch + step)

                avg_loss = total_loss / steps_per_epoch
                loss_history.append(avg_loss)
                print(f"Avg Loss: {avg_loss:.5f}")

                saver.save(sess, os.path.join(train_dir, "model.ckpt"), global_step=epoch)

            print(" Training complete. Saving loss plot...")

            plt.figure()
            plt.plot(range(1, num_epochs + 1), loss_history, marker='o')
            plt.xlabel("Epoch")
            plt.ylabel("Average Loss")
            plt.title("Training Loss per Epoch")
            plt.grid(True)
            plt.savefig(os.path.join(train_dir, "loss_curve.png"))
            plt.show()

# %%
train_epochwise_using_triplets(
    triplets_txt_path="D:/VFI/CyclicGen/triplets.txt",
    batch_size=4,
    num_epochs=10,
    train_dir="training_logs"
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 train_epochwise_using_triplets(
#       2     triplets_txt_path="D:/VFI/CyclicGen/triplets.txt",
#       3     batch_size=4,
#       4     num_epochs=10,
#       5     train_dir="training_logs"
#       6 )
#
# Cell In[39], line 10, in train_epochwise_using_triplets(triplets_txt_path, batch_size, num_epochs, train_dir)
#       7 dataset_size = len(f1_list)
#       8 steps_per_epoch = dataset_size // batch_size
# ---> 10 it1 = iter(create_dataset(f1_list, batch_size))
#      11 it2 = iter(create_dataset(f2_list, batch_size))
#      12 it3 = iter(create_dataset(f3_list, batch_size))
#
# Cell In[36], line 5, in create_dataset(file_list, batch_size)
#       3 image_ds = path_ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
#       4 image_ds = image_ds.batch(batch_size).repeat()
# ----> 5 return iter(image_ds)
#
# File c:\Users\hp\anaconda3\envs\dl-gpu\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499     return iterator_ops.OwnedIterator(self)
#     500 else:
# --> 501   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     502                      "iteration in eager mode or within tf.function.")
#
# RuntimeError: `tf.data.Dataset` only supports Python-style iteration in eager mode or within tf.function.
